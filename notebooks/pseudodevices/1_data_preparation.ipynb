# %%
from pathlib import Path
from IPython.display import display
import warnings
import contextlib
import io
import sys
from matplotlib.pylab import plt
from tqdm import tqdm

import pandas as pd
import numpy as np

from eegdash.dataset import EEGChallengeDataset
from braindecode.datasets.base import BaseConcatDataset

pd.set_option('display.max_columns', 50)

# %% [markdown]
# Input: release_list
# Output:
# - train_dataset.pkl
# - valid_dataset.pkl
# - train_dataset_5sec.pkl

# %% [markdown]
# ## Step 1 - Prepare full Contrast Change Dataset for every release
#
# Could be very long for first time, for testing you could choose only one release to save your time
#
# If you already downloaded the data from eegdash - simply choose the corresponding cached dir to save your time

# %%
# save the source data in root directory
DATA_DIR = Path("../../data")
DATA_DIR.mkdir(parents=True, exist_ok=True)

# %%
def prepare_full_dataset(data_dir, release_list):
    all_datasets_list = []
    buf = io.StringIO()

    for release in tqdm(release_list, file=sys.stdout):
        with contextlib.redirect_stderr(buf):
            ds = EEGChallengeDataset(
                release=release,
                task="contrastChangeDetection",
                mini=False,
                description_fields=[
                    "subject","session","run","task",
                    "age","gender","sex","p_factor",
                ],
                cache_dir=data_dir,
            )
        all_datasets_list.append(ds)

    return BaseConcatDataset(all_datasets_list)

# %%
release_list = ["R" + str(idx) for idx in range(1, 3)]
print(f"Release list: {release_list}")

dataset_ccd = prepare_full_dataset(data_dir=DATA_DIR, release_list=release_list)
display(dataset_ccd.description)
# Out:
# Release list: ['R1', 'R2']
# 100%|██████████| 2/2 [00:06<00:00,  3.09s/it]
#           subject  run                     task      age sex  p_factor  \
# 0    NDARAC904DMU    1  contrastChangeDetection  11.3386   F    -0.603
# 1    NDARAC904DMU    3  contrastChangeDetection  11.3386   F    -0.603
# 2    NDARAC904DMU    2  contrastChangeDetection  11.3386   F    -0.603
# 3    NDARAG143ARJ    3  contrastChangeDetection   7.6648   M    -0.258
# 4    NDARAG143ARJ    1  contrastChangeDetection   7.6648   M    -0.258
# ..            ...  ...                      ...      ...  ..       ...
# 589  NDARZK732FZ0    1  contrastChangeDetection  15.4212   M     0.741
# 590  NDARZK732FZ0    3  contrastChangeDetection  15.4212   M     0.741
# 591  NDARZL855WVA    3  contrastChangeDetection  14.6656   F     0.824
# 592  NDARZL855WVA    1  contrastChangeDetection  14.6656   F     0.824
# 593  NDARZL855WVA    2  contrastChangeDetection  14.6656   F     0.824
#
#     release_number  ehq_total commercial_use full_pheno  attention  \
# 0               R1      71.17            Yes        Yes     -0.446
# 1               R1      71.17            Yes        Yes     -0.446
# 2               R1      71.17            Yes        Yes     -0.446
# 3               R1     100.05            Yes        Yes     -0.425
# 4               R1     100.05            Yes        Yes     -0.425
# ..             ...        ...            ...        ...        ...
# 589             R2      66.70            Yes        Yes     -0.588
# 590             R2      66.70            Yes        Yes     -0.588
# 591             R2      95.65            Yes        Yes     -0.797
# 592             R2      95.65            Yes        Yes     -0.797
# 593             R2      95.65            Yes        Yes     -0.797
#
#      internalizing  externalizing restingstate despicableme funwithfractals  \
# 0            1.248          0.325    available    available       available
# 1            1.248          0.325    available    available       available
# 2            1.248          0.325    available    available       available
# 3            1.006          0.509    available    available       available
# 4            1.006          0.509    available    available       available
# ..             ...            ...          ...          ...             ...
# 589          0.761          0.269    available    available       available
# 590          0.761          0.269    available    available       available
# 591          0.141          0.893    available    available       available
# 592          0.141          0.893    available    available       available
# 593          0.141          0.893    available    available       available
#
#     thepresent diaryofawimpykid contrastchangedetection_1  \
# 0    available        available                 available
# 1    available        available                 available
# 2    available        available                 available
# 3    available        available                 available
# 4    available        available                 available
# ..         ...              ...                       ...
# 589  available        available                 available
# 590  available        available                 available
# 591  available        available                 available
# 592  available        available                 available
# 593  available        available                 available
#
#     contrastchangedetection_2 contrastchangedetection_3 surroundsupp_1  \
# 0                   available                 available      available
# 1                   available                 available      available
# 2                   available                 available      available
# 3                   available                 available      available
# 4                   available                 available      available
# ..                        ...                       ...            ...
# 589                 available                 available      available
# 590                 available                 available      available
# 591                 available                 available      available
# 592                 available                 available      available
# 593                 available                 available      available
#
#     surroundsupp_2 seqlearning6target seqlearning8target symbolsearch
# 0        available        unavailable          available    available
# 1        available        unavailable          available    available
# 2        available        unavailable          available    available
# 3        available          available        unavailable      caution
# 4        available          available        unavailable      caution
# ..             ...                ...                ...          ...
# 589      available        unavailable          available      caution
# 590      available        unavailable          available      caution
# 591      available        unavailable          available      caution
# 592      available        unavailable          available      caution
# 593      available        unavailable          available      caution
#
# [594 rows x 26 columns]

# %% [markdown]
# ### Task 2 targets visualization
#
# Congratulations!
# We already have all required data for Contrast Change Task on run level

# %%
dataset_ccd.description.externalizing.hist(bins=20)
plt.title("Externalizing - task 2 target")
plt.xlabel("Externalizing score")
plt.ylabel("Number of subjects")
plt.show()

# %%
n_subjects = dataset_ccd.description.subject.nunique()
print(f"Number of unique subjects in total: {n_subjects}")
# Out:
# Number of unique subjects in total: 209

# %% [markdown]
# ### Step 2 — Prepare annotation for window extraction
#
# In this step we prepare the data for training a model that predicts reaction speed.
#
# To do so, we will later cut long run-level EEG recordings into short, stimulus-locked segments.
#
# Here we only prepare the annotations that define where each trial and stimulus occurs, so the recordings can be efficiently split into fixed-length windows in the next step.
#
# 1. **`annotate_trials_with_target`**
#    - Finds stimulus/response events and computes the target `rt_from_stimulus` (reaction time).
# 2. **`add_aux_anchors`**
#    - Adds helper anchor events used to align future windows.

# %%
from braindecode.preprocessing import preprocess, Preprocessor, create_windows_from_events
from eegdash.hbn.windows import (
    annotate_trials_with_target,
    add_aux_anchors,
    add_extras_columns,
    keep_only_recordings_with,
)

warnings.filterwarnings(
    "ignore", message="Omitted .* annotation.*outside data range", category=RuntimeWarning
)

EPOCH_LEN_S = 2.0
SFREQ = 100

transformation_offline = [
    Preprocessor(
        annotate_trials_with_target,
        target_field="rt_from_stimulus", epoch_length=EPOCH_LEN_S,
        require_stimulus=True, require_response=True,
        apply_on_array=False,
    ),
    Preprocessor(add_aux_anchors, apply_on_array=False),
]
preprocess(dataset_ccd, transformation_offline, n_jobs=1)

# %% [markdown]
# ### Annotations on current step looks like this:

# %%
raw = dataset_ccd.datasets[0].raw
ann = raw.annotations.to_data_frame()
ann
# Out:
#                      onset  duration           description    anchor  correct  \
# 0  2025-08-19 11:53:39.484       2.0  contrast_trial_start       NaN        1
# 1  2025-08-19 11:53:42.284       0.0       stimulus_anchor  stimulus        1
# 2  2025-08-19 11:53:44.414       0.0       response_anchor  response        1
# 3  2025-08-19 11:53:44.684       2.0  contrast_trial_start       NaN        1
# 4  2025-08-19 11:53:47.484       0.0       stimulus_anchor  stimulus        1
# ..                     ...       ...                   ...       ...      ...
# 61 2025-08-19 11:56:11.888       0.0       stimulus_anchor  stimulus        1
# 62 2025-08-19 11:56:13.578       0.0       response_anchor  response        1
# 63 2025-08-19 11:56:14.288       2.0  contrast_trial_start       NaN        1
# 64 2025-08-19 11:56:20.288       0.0       stimulus_anchor  stimulus        1
# 65 2025-08-19 11:56:21.508       0.0       response_anchor  response        1
#
#     response_onset      response_type  rt_from_stimulus  rt_from_trialstart  \
# 0           44.414  right_buttonPress              2.13                4.93
# 1           44.414  right_buttonPress              2.13                4.93
# 2           44.414  right_buttonPress              2.13                4.93
# 3           49.444  right_buttonPress              1.96                4.76
# 4           49.444  right_buttonPress              1.96                4.76
# ..             ...                ...               ...                 ...
# 61         193.578  right_buttonPress              1.69                4.49
# 62         193.578  right_buttonPress              1.69                4.49
# 63         201.508  right_buttonPress              1.22                7.22
# 64         201.508  right_buttonPress              1.22                7.22
# 65         201.508  right_buttonPress              1.22                7.22
#
#     stimulus_onset  target
# 0           42.284    2.13
# 1           42.284    2.13
# 2           42.284    2.13
# 3           47.484    1.96
# 4           47.484    1.96
# ..             ...     ...
# 61         191.888    1.69
# 62         191.888    1.69
# 63         200.288    1.22
# 64         200.288    1.22
# 65         200.288    1.22
#
# [66 rows x 11 columns]

# %% [markdown]
# ## Step 3 — Select recordings with valid stimulus anchors
#
# We now define the parameters for window extraction:
# - ANCHOR = "stimulus_anchor" (the event to align windows to),
# - SHIFT_AFTER_STIM = 0.5 s (window start delay after the stimulus),
# - and WINDOW_LEN = 2.0 s (window duration).

# %%
ANCHOR = "stimulus_anchor"

SHIFT_AFTER_STIM = 0.5
WINDOW_LEN       = 2.0

# Keep only recordings that actually contain stimulus anchors
dataset = keep_only_recordings_with(ANCHOR, dataset_ccd)

raw = dataset.datasets[0].raw
ann = raw.annotations.to_data_frame()
ann
# Out:
#                      onset  duration           description    anchor  correct  \
# 0  2025-08-19 11:53:39.484       2.0  contrast_trial_start       NaN        1
# 1  2025-08-19 11:53:42.284       0.0       stimulus_anchor  stimulus        1
# 2  2025-08-19 11:53:44.414       0.0       response_anchor  response        1
# 3  2025-08-19 11:53:44.684       2.0  contrast_trial_start       NaN        1
# 4  2025-08-19 11:53:47.484       0.0       stimulus_anchor  stimulus        1
# ..                     ...       ...                   ...       ...      ...
# 61 2025-08-19 11:56:11.888       0.0       stimulus_anchor  stimulus        1
# 62 2025-08-19 11:56:13.578       0.0       response_anchor  response        1
# 63 2025-08-19 11:56:14.288       2.0  contrast_trial_start       NaN        1
# 64 2025-08-19 11:56:20.288       0.0       stimulus_anchor  stimulus        1
# 65 2025-08-19 11:56:21.508       0.0       response_anchor  response        1
#
#     response_onset      response_type  rt_from_stimulus  rt_from_trialstart  \
# 0           44.414  right_buttonPress              2.13                4.93
# 1           44.414  right_buttonPress              2.13                4.93
# 2           44.414  right_buttonPress              2.13                4.93
# 3           49.444  right_buttonPress              1.96                4.76
# 4           49.444  right_buttonPress              1.96                4.76
# ..             ...                ...               ...                 ...
# 61         193.578  right_buttonPress              1.69                4.49
# 62         193.578  right_buttonPress              1.69                4.49
# 63         201.508  right_buttonPress              1.22                7.22
# 64         201.508  right_buttonPress              1.22                7.22
# 65         201.508  right_buttonPress              1.22                7.22
#
#     stimulus_onset  target
# 0           42.284    2.13
# 1           42.284    2.13
# 2           42.284    2.13
# 3           47.484    1.96
# 4           47.484    1.96
# ..             ...     ...
# 61         191.888    1.69
# 62         191.888    1.69
# 63         200.288    1.22
# 64         200.288    1.22
# 65         200.288    1.22
#
# [66 rows x 11 columns]

# %% [markdown]
# ## Step 4 — Remove late stimulus anchors
#
# Before window extraction, we drop stimulus anchors that occur too close to the end of a recording:
#     - when a full 2 s window would not fit.
#
# This step filters out those late events and reports how many anchors were removed per run, keeping only recordings with valid stimulus_anchor annotations.

# %%
def remove_late_anchors(dataset, anchor='stimulus_anchor', shift=SHIFT_AFTER_STIM, winlen=WINDOW_LEN):
    log = []
    for i, bd in enumerate(dataset.datasets):
        raw = bd.raw
        ann = raw.annotations
        T = float(raw.times[-1])

        desc  = np.asarray(ann.description, dtype=str)
        onset = np.asarray(ann.onset, dtype=float)

        is_anchor = (desc == anchor)
        n_before = int(is_anchor.sum())
        too_late = is_anchor & ((onset + shift + winlen) > T + 1e-9)
        n_removed = int(too_late.sum())
        if n_removed > 0:
            log.append({
                "idx": i,
                "subject": bd.description.get("subject", "NA"),
                "run": bd.description.get("run", "NA"),
                "release": bd.description.get("release_number", "NA"),
                "n_anchors_before": n_before,
                "n_removed": n_removed,
                "max_onset_removed": float(onset[too_late].max()),
                "rec_len_s": T
            })
        keep = ~too_late
        idx = np.where(keep)[0]
        raw.set_annotations(ann[idx], verbose=False)
    if len(log) > 0:
        df_log = pd.DataFrame(log).sort_values(["n_removed","n_anchors_before"], ascending=False)
        print(f"Removed stimuls in total: {int(df_log['n_removed'].sum()) if len(df_log)>0 else 0}")
        print(f"Records removed: {len(df_log)}")
        display(df_log.head(20))
    dataset = keep_only_recordings_with(ANCHOR, dataset)
    return dataset

# %%
dataset = remove_late_anchors(dataset, ANCHOR, SHIFT_AFTER_STIM, WINDOW_LEN)
dataset

# %% [markdown]
# ## Step 5 — Final window extraction and metadata injection
#
# Now we cut each recording into 2-second stimulus-locked windows (starting 0.5 s after stimulus onset) and attach trial metadata such as reaction time, correctness, and response type.
# The result single_windows is the complete training dataset of EEG segments aligned to stimuli, ready for model input.

# %%
import contextlib
import io

buf = io.StringIO()
with contextlib.redirect_stdout(buf):
    single_windows = create_windows_from_events(
        dataset,
        mapping={ANCHOR: 0},
        trial_start_offset_samples=int(SHIFT_AFTER_STIM * SFREQ),                 # +0.5 s
        trial_stop_offset_samples=int((SHIFT_AFTER_STIM + WINDOW_LEN) * SFREQ),   # +2.5 s
        window_size_samples=int(EPOCH_LEN_S * SFREQ),
        window_stride_samples=SFREQ,
        preload=True,
    )

# Injecting metadata into the extra mne annotation.
single_windows = add_extras_columns(
    single_windows,
    dataset,
    desc=ANCHOR,
    keys=("target", "rt_from_stimulus", "rt_from_trialstart",
          "stimulus_onset", "response_onset", "correct", "response_type")
          )

# %%
meta_information = single_windows.get_metadata()
display(meta_information)

fig, ax = plt.subplots(figsize=(15, 5))
ax = meta_information["target"].plot.hist(bins=30, ax=ax, color='lightblue')
ax.set_xlabel("Response Time (s)")
ax.set_ylabel("Frequency")
ax.set_title("Distribution of Response Times")
plt.show()
# Out:
#     i_window_in_trial  i_start_in_trial  i_stop_in_trial  target  \
# 0                   0              4278             4478    2.13
# 1                   0              4798             4998    1.96
# 2                   0              5478             5678    2.02
# 3                   0              6318             6518    1.72
# 4                   0              6838             7038     1.8
# ..                ...               ...              ...     ...
# 37                  0             61742            61942    1.68
# 38                  0             62262            62462    2.28
# 39                  0             62942            63142    2.04
# 40                  0             64462            64662    1.16
# 41                  0             65302            65502    1.61
#
#     rt_from_stimulus  rt_from_trialstart  stimulus_onset  response_onset  \
# 0               2.13                4.93          42.284          44.414
# 1               1.96                4.76          47.484          49.444
# 2               2.02                6.42          54.284          56.304
# 3               1.72                7.72          62.684          64.404
# 4                1.8                 4.6          67.884          69.684
# ..               ...                 ...             ...             ...
# 37              1.68                4.48         616.918         618.598
# 38              2.28                5.08         622.118         624.398
# 39              2.04                6.44         628.918         630.958
# 40              1.16                7.16         644.118         645.278
# 41              1.61                7.61         652.518         654.128
#
#     correct      response_type       subject  run                     task  \
# 0         1  right_buttonPress  NDARAC904DMU    1  contrastChangeDetection
# 1         1  right_buttonPress  NDARAC904DMU    1  contrastChangeDetection
# 2         1  right_buttonPress  NDARAC904DMU    1  contrastChangeDetection
# 3         1  right_buttonPress  NDARAC904DMU    1  contrastChangeDetection
# 4         1   left_buttonPress  NDARAC904DMU    1  contrastChangeDetection
# ..      ...                ...           ...  ...                      ...
# 37        1  right_buttonPress  NDARZL855WVA    2  contrastChangeDetection
# 38        1  right_buttonPress  NDARZL855WVA    2  contrastChangeDetection
# 39        1   left_buttonPress  NDARZL855WVA    2  contrastChangeDetection
# 40        1  right_buttonPress  NDARZL855WVA    2  contrastChangeDetection
# 41        1   left_buttonPress  NDARZL855WVA    2  contrastChangeDetection
#
#         age sex  p_factor release_number  ehq_total commercial_use full_pheno  \
# 0   11.3386   F    -0.603             R1      71.17            Yes        Yes
# 1   11.3386   F    -0.603             R1      71.17            Yes        Yes
# 2   11.3386   F    -0.603             R1      71.17            Yes        Yes
# 3   11.3386   F    -0.603             R1      71.17            Yes        Yes
# 4   11.3386   F    -0.603             R1      71.17            Yes        Yes
# ..      ...  ..       ...            ...        ...            ...        ...
# 37  14.6656   F     0.824             R2      95.65            Yes        Yes
# 38  14.6656   F     0.824             R2      95.65            Yes        Yes
# 39  14.6656   F     0.824             R2      95.65            Yes        Yes
# 40  14.6656   F     0.824             R2      95.65            Yes        Yes
# 41  14.6656   F     0.824             R2      95.65            Yes        Yes
#
#     attention  internalizing  externalizing restingstate despicableme  \
# 0      -0.446          1.248          0.325    available    available
# 1      -0.446          1.248          0.325    available    available
# 2      -0.446          1.248          0.325    available    available
# 3      -0.446          1.248          0.325    available    available
# 4      -0.446          1.248          0.325    available    available
# ..        ...            ...            ...          ...          ...
# 37     -0.797          0.141          0.893    available    available
# 38     -0.797          0.141          0.893    available    available
# 39     -0.797          0.141          0.893    available    available
# 40     -0.797          0.141          0.893    available    available
# 41     -0.797          0.141          0.893    available    available
#
#    funwithfractals thepresent diaryofawimpykid contrastchangedetection_1  \
# 0        available  available        available                 available
# 1        available  available        available                 available
# 2        available  available        available                 available
# 3        available  available        available                 available
# 4        available  available        available                 available
# ..             ...        ...              ...                       ...
# 37       available  available        available                 available
# 38       available  available        available                 available
# 39       available  available        available                 available
# 40       available  available        available                 available
# 41       available  available        available                 available
#
#    contrastchangedetection_2 contrastchangedetection_3 surroundsupp_1  \
# 0                  available                 available      available
# 1                  available                 available      available
# 2                  available                 available      available
# 3                  available                 available      available
# 4                  available                 available      available
# ..                       ...                       ...            ...
# 37                 available                 available      available
# 38                 available                 available      available
# 39                 available                 available      available
# 40                 available                 available      available
# 41                 available                 available      available
#
#    surroundsupp_2 seqlearning6target seqlearning8target symbolsearch
# 0       available        unavailable          available    available
# 1       available        unavailable          available    available
# 2       available        unavailable          available    available
# 3       available        unavailable          available    available
# 4       available        unavailable          available    available
# ..            ...                ...                ...          ...
# 37      available        unavailable          available      caution
# 38      available        unavailable          available      caution
# 39      available        unavailable          available      caution
# 40      available        unavailable          available      caution
# 41      available        unavailable          available      caution
#
# [14881 rows x 36 columns]

# %% [markdown]
# # train test split

# %%
from sklearn.model_selection import train_test_split
from sklearn.utils import check_random_state

valid_frac = 0.2
seed = 2025

meta_information = single_windows.description

subjects = meta_information["subject"].unique()

train_subj, valid_subj = train_test_split(
    subjects, test_size=valid_frac, random_state=check_random_state(seed), shuffle=True
)

# %%
# and finally using braindecode split function, we can do:
subject_split = single_windows.split("subject")

train_set = []
valid_set = []

for s in subject_split:
    if s in train_subj:
        train_set.append(subject_split[s])
    elif s in valid_subj:
        valid_set.append(subject_split[s])

train_set = BaseConcatDataset(train_set)
valid_set = BaseConcatDataset(valid_set)

print("Number of examples in each split in the minirelease")
print(f"Train:\t{len(train_set)}")
print(f"Valid:\t{len(valid_set)}")
# Out:
# Number of examples in each split in the minirelease
# Train:	11667
# Valid:	3214

# %%
import pickle
import os
artefacts_dir = '../../artefacts/data'
os.makedirs(artefacts_dir, exist_ok=True)

with open(os.path.join(artefacts_dir, "train_dataset.pkl"), "wb") as f:
    pickle.dump(train_set, f)

with open(os.path.join(artefacts_dir, "valid_dataset.pkl"), "wb") as f:
    pickle.dump(valid_set, f)

# %% [markdown]
# ## Prepare larger windows for training
#
# Just repeat steps 4-6 with larger WINDOW_LEN

# %%
from copy import deepcopy 

ANCHOR = "stimulus_anchor"

SHIFT_AFTER_STIM = 0.0
WINDOW_LEN       = 5.0   
TRIAL_LEN_S = 5.0        
EPOCH_LEN_S = 5.

dataset_5s = deepcopy(dataset_ccd) 
dataset_5s = keep_only_recordings_with(ANCHOR, dataset_5s)
dataset_5s = remove_late_anchors(dataset_5s, ANCHOR, SHIFT_AFTER_STIM, WINDOW_LEN)
# Out:
# Removed stimuls in total: 2
# Records removed: 2
#    idx       subject  run release  n_anchors_before  n_removed  \
# 1  491  NDARPH844KP2    3      R2                24          1
# 0  151  NDARNR773DL4    3      R1                22          1
#
#    max_onset_removed  rec_len_s
# 1            322.266     324.99
# 0            752.436     754.99

# %%
import contextlib
import io

buf = io.StringIO()
with contextlib.redirect_stdout(buf):
    single_windows_5s = create_windows_from_events(
        dataset_5s,
        mapping={ANCHOR: 0},
        trial_start_offset_samples=int(SHIFT_AFTER_STIM * SFREQ),                 # +0.5 s
        trial_stop_offset_samples=int((SHIFT_AFTER_STIM + WINDOW_LEN) * SFREQ),   # +5.5 s
        window_size_samples=int(EPOCH_LEN_S * SFREQ),
        window_stride_samples=SFREQ,
        preload=True,
    )

single_windows_5s = add_extras_columns(
    single_windows_5s,
    dataset_5s,
    desc=ANCHOR,
    keys=("target", "rt_from_stimulus", "rt_from_trialstart",
          "stimulus_onset", "response_onset", "correct", "response_type")
          )

# %%
meta_information = single_windows_5s.get_metadata()
display(meta_information)

fig, ax = plt.subplots(figsize=(15, 5))
ax = meta_information["target"].plot.hist(bins=30, ax=ax, color='lightblue')
ax.set_xlabel("Response Time (s)")
ax.set_ylabel("Frequency")
ax.set_title("Distribution of Response Times")
plt.show()
# Out:
#     i_window_in_trial  i_start_in_trial  i_stop_in_trial  target  \
# 0                   0              4228             4728    2.13
# 1                   0              4748             5248    1.96
# 2                   0              5428             5928    2.02
# 3                   0              6268             6768    1.72
# 4                   0              6788             7288     1.8
# ..                ...               ...              ...     ...
# 37                  0             61692            62192    1.68
# 38                  0             62212            62712    2.28
# 39                  0             62892            63392    2.04
# 40                  0             64412            64912    1.16
# 41                  0             65252            65752    1.61
#
#     rt_from_stimulus  rt_from_trialstart  stimulus_onset  response_onset  \
# 0               2.13                4.93          42.284          44.414
# 1               1.96                4.76          47.484          49.444
# 2               2.02                6.42          54.284          56.304
# 3               1.72                7.72          62.684          64.404
# 4                1.8                 4.6          67.884          69.684
# ..               ...                 ...             ...             ...
# 37              1.68                4.48         616.918         618.598
# 38              2.28                5.08         622.118         624.398
# 39              2.04                6.44         628.918         630.958
# 40              1.16                7.16         644.118         645.278
# 41              1.61                7.61         652.518         654.128
#
#     correct      response_type       subject  run                     task  \
# 0         1  right_buttonPress  NDARAC904DMU    1  contrastChangeDetection
# 1         1  right_buttonPress  NDARAC904DMU    1  contrastChangeDetection
# 2         1  right_buttonPress  NDARAC904DMU    1  contrastChangeDetection
# 3         1  right_buttonPress  NDARAC904DMU    1  contrastChangeDetection
# 4         1   left_buttonPress  NDARAC904DMU    1  contrastChangeDetection
# ..      ...                ...           ...  ...                      ...
# 37        1  right_buttonPress  NDARZL855WVA    2  contrastChangeDetection
# 38        1  right_buttonPress  NDARZL855WVA    2  contrastChangeDetection
# 39        1   left_buttonPress  NDARZL855WVA    2  contrastChangeDetection
# 40        1  right_buttonPress  NDARZL855WVA    2  contrastChangeDetection
# 41        1   left_buttonPress  NDARZL855WVA    2  contrastChangeDetection
#
#         age sex  p_factor release_number  ehq_total commercial_use full_pheno  \
# 0   11.3386   F    -0.603             R1      71.17            Yes        Yes
# 1   11.3386   F    -0.603             R1      71.17            Yes        Yes
# 2   11.3386   F    -0.603             R1      71.17            Yes        Yes
# 3   11.3386   F    -0.603             R1      71.17            Yes        Yes
# 4   11.3386   F    -0.603             R1      71.17            Yes        Yes
# ..      ...  ..       ...            ...        ...            ...        ...
# 37  14.6656   F     0.824             R2      95.65            Yes        Yes
# 38  14.6656   F     0.824             R2      95.65            Yes        Yes
# 39  14.6656   F     0.824             R2      95.65            Yes        Yes
# 40  14.6656   F     0.824             R2      95.65            Yes        Yes
# 41  14.6656   F     0.824             R2      95.65            Yes        Yes
#
#     attention  internalizing  externalizing restingstate despicableme  \
# 0      -0.446          1.248          0.325    available    available
# 1      -0.446          1.248          0.325    available    available
# 2      -0.446          1.248          0.325    available    available
# 3      -0.446          1.248          0.325    available    available
# 4      -0.446          1.248          0.325    available    available
# ..        ...            ...            ...          ...          ...
# 37     -0.797          0.141          0.893    available    available
# 38     -0.797          0.141          0.893    available    available
# 39     -0.797          0.141          0.893    available    available
# 40     -0.797          0.141          0.893    available    available
# 41     -0.797          0.141          0.893    available    available
#
#    funwithfractals thepresent diaryofawimpykid contrastchangedetection_1  \
# 0        available  available        available                 available
# 1        available  available        available                 available
# 2        available  available        available                 available
# 3        available  available        available                 available
# 4        available  available        available                 available
# ..             ...        ...              ...                       ...
# 37       available  available        available                 available
# 38       available  available        available                 available
# 39       available  available        available                 available
# 40       available  available        available                 available
# 41       available  available        available                 available
#
#    contrastchangedetection_2 contrastchangedetection_3 surroundsupp_1  \
# 0                  available                 available      available
# 1                  available                 available      available
# 2                  available                 available      available
# 3                  available                 available      available
# 4                  available                 available      available
# ..                       ...                       ...            ...
# 37                 available                 available      available
# 38                 available                 available      available
# 39                 available                 available      available
# 40                 available                 available      available
# 41                 available                 available      available
#
#    surroundsupp_2 seqlearning6target seqlearning8target symbolsearch
# 0       available        unavailable          available    available
# 1       available        unavailable          available    available
# 2       available        unavailable          available    available
# 3       available        unavailable          available    available
# 4       available        unavailable          available    available
# ..            ...                ...                ...          ...
# 37      available        unavailable          available      caution
# 38      available        unavailable          available      caution
# 39      available        unavailable          available      caution
# 40      available        unavailable          available      caution
# 41      available        unavailable          available      caution
#
# [14879 rows x 36 columns]

# %% [markdown]
# ## Same Train/Valid Split

# %%
subject_split = single_windows_5s.split("subject")

train_set = []
valid_set = []

for s in subject_split:
    if s in valid_subj:
        valid_set.append(subject_split[s])
    else:
        train_set.append(subject_split[s])

train_set = BaseConcatDataset(train_set)
valid_set = BaseConcatDataset(valid_set)

print("Number of examples in each split in the minirelease")
print(f"Train:\t{len(train_set)}")
print(f"Valid:\t{len(valid_set)}")
# Out:
# Number of examples in each split in the minirelease
# Train:	11665
# Valid:	3214

# %%
with open(os.path.join(artefacts_dir, "train_dataset_5sec.pkl"), "wb") as f:
    pickle.dump(train_set, f)

with open(os.path.join(artefacts_dir, "valid_dataset_5sec.pkl"), "wb") as f:
    pickle.dump(valid_set, f)
